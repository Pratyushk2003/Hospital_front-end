# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratyushk2003/Hospital_front-end/blob/main/Untitled24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel('/Copy of Epilepsy_testing_data_doctor_with_original_one_hot(1).xlsx')
df1 = pd.read_excel('/Copy of Testing_data(1).xlsx')

# %%
result = df.merge(df1.iloc[:, [0]], left_on=df.columns[0], right_on=df1.columns[0], how='inner')

# %%
result
# Out:
#     Unnamed: 0  PatientAge  Gender wandering_headbanging_observation  \
# 0            0        18.0  Female                                No
# 1            2        17.0    Male                                No
# 2            9        16.0    Male                                No
# 3           11        19.0  Female                                No
# 4           15        12.0  Female                                No
# ..         ...         ...     ...                               ...
# 94         489        30.0    Male                                No
# 95         490        22.0    Male                               Yes
# 96         492        20.0    Male                                No
# 97         493        25.0    Male                                No
# 98         494        28.0    Male                                No
#
#    eyes_closed_during_event weeping_before_during_after_episode  \
# 0                       Yes                                 Yes
# ...

# %%
# Save the result DataFrame to a new Excel file
result.to_excel('result.xlsx', index=False)
